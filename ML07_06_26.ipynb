# %%
# Out:
#   File "/tmp/ipykernel_1207/1834260460.py", line 2
#     inport padndas as pd
#            ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

print("Numpy_Version: ", np.__version__)
print("Pandas Version: ", pd.__version__)
print("Matplotlib Version: ", matplotlib.__version__)
# Out:
# Numpy_Version:  2.0.2
# Pandas Version:  2.2.2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1207/2463977380.py in <cell line: 0>()
#       6 print("Numpy_Version: ", np.__version__)
#       7 print("Pandas Version: ", pd.__version__)
# ----> 8 print("Matplotlib Version: ", plt.__version__)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute '__version__'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from sklearn.linear_model import LinearRegression

print("Numpy Version:", np.__version__)
print("Pandas Version:", pd.__version__)
print("Matplotlib Version:", matplotlib.__version__)
# Out:
# Numpy Version: 2.0.2
# Pandas Version: 2.2.2
# Matplotlib Version: 3.10.0

# %%
import numpy as np
scores = np.array([10,20,30,40,50])
print(scores)
print(type(scores))

student_data = np.array([['Alice',25],['Bob',30],['Charlie',35]])
print(student_data)
# Out:
# [10 20 30 40 50]
# <class 'numpy.ndarray'>
# [['Alice' '25']
#  ['Bob' '30']
#  ['Charlie' '35']]

# %%
marks = np.array([85,90,78,92,88])
print(marks + 5)
print(marks * 2)
print(marks / 100)
print(marks - 10)

print("Mean :", np.mean(marks))
print("std :", np.std(marks))
print("max :", np.max(marks))
print("min :", np.min(marks))
# Out:
# [90 95 83 97 93]
# [170 180 156 184 176]
# [0.85 0.9  0.78 0.92 0.88]
# [75 80 68 82 78]
# Mean : 86.6
# std : 4.882622246293481
# max : 92
# min : 78

# %%
# Reshaping - ML operation to add features to sample size (reshape one array to columns and rows of matrix),

flat = np.array([1,2,3,4,5,6])
matrix = flat.reshape(2,3)
print(matrix)
print(flat)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [1 2 3 4 5 6]

# %%
import pandas as pd
# Create data frame manuually
data = {
    "Name": ["Rahul", "Priya", "Amit", "Sneha", "Kiran"],
    'Age' : [22,25,28,24,30],
    'Score' : [85,92,78,88,95],
    'Passed' : [True, True, True, True, True]
}
df = pd.DataFrame(data)
print(df)
print(type(data))
# Out:
#     Name  Age  Score  Passed
# 0  Rahul   22     85    True
# 1  Priya   25     92    True
# 2   Amit   28     78    True
# 3  Sneha   24     88    True
# 4  Kiran   30     95    True
# <class 'dict'>

# %%
# Load from CSV


# or from URL
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)

# print(df.shape)        # (891, 12) → 891 passengers, 12 columns
# print(df.head(5))       # First 5 rows
# print(df.tail(3))      # Last 3 rows
# print(df.columns)      # Column names
# print(df.describe)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
#Filter and sort
ages=df['Age']

subset = df[['Name', 'Fare']]

high_scores = df[df['Fare'] > 100]
print(high_scores)

young_toppers = df[(df['Age'] > 75) & (df['Fare']>100)]
print(young_toppers)
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)

# ── STEP 1: Basic overview ──────────────────────────────
print("Shape:", df.shape)
print("\nFirst look:")
print(df.head())
print("\nMissing values:")
print(df.isnull().sum())
print("\nData types:")
print(df.dtypes)

# ── STEP 2: Survival rate ───────────────────────────────
survival_rate = df['Survived'].value_counts()
print(f"\nSurvived: {survival_rate[1]} | Died: {survival_rate[0]}")

# ── STEP 3: Visualize survival by gender ────────────────
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
df['Survived'].value_counts().plot(kind='bar', color=['red','green'])
plt.title('Survival Count')
plt.xticks([0,1], ['Died','Survived'], rotation=0)

plt.subplot(1, 3, 2)
sns.barplot(x='Sex', y='Survived', data=df)
plt.title('Survival Rate by Gender')

plt.subplot(1, 3, 3)
sns.barplot(x='Pclass', y='Survived', data=df)
plt.title('Survival Rate by Class')

plt.tight_layout()
plt.show()

# ── STEP 4: Age distribution ────────────────────────────
plt.figure(figsize=(8, 4))
df['Age'].dropna().hist(bins=30, color='green', edgecolor='black')
plt.title('Age Distribution of Passengers')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# ── STEP 5: Correlation heatmap ─────────────────────────
plt.figure(figsize=(8, 5))
numeric_df = df.select_dtypes(include='number')
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Feature Correlation Heatmap')
plt.show()
# Out:
# Shape: (891, 12)
#
# First look:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...
